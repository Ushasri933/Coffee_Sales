# %%
import pandas as pd
CS=pd.read_excel("/content/Coffe_sales.xlsx")
CS
# Out:
#            date                datetime  hour_of_day cash_type  \
# 0    2024-03-01 2024-03-01 10:15:50.520           10      card
# 1    2024-03-01 2024-03-01 12:19:22.539           12      card
# 2    2024-03-01 2024-03-01 12:20:18.089           12      card
# 3    2024-03-01 2024-03-01 13:46:33.006           13      card
# 4    2024-03-01 2024-03-01 13:48:14.626           13      card
# ...         ...                     ...          ...       ...
# 3631 2025-03-23 2025-03-23 10:34:54.894           10      card
# 3632 2025-03-23 2025-03-23 14:43:37.362           14      card
# 3633 2025-03-23 2025-03-23 14:44:16.864           14      card
# 3634 2025-03-23 2025-03-23 15:47:28.723           15      card
# 3635 2025-03-23 2025-03-23 18:11:38.635           18      card
#
#                      card  money    coffee_name Time_of_Day Weekday  \
# 0     ANON-0000-0000-0001  38.70          Latte     Morning     Fri
# 1     ANON-0000-0000-0002  38.70  Hot Chocolate   Afternoon     Fri
# ...

# %%
CS.head()
# Out:
#         date                datetime  hour_of_day cash_type  \
# 0 2024-03-01 2024-03-01 10:15:50.520           10      card
# 1 2024-03-01 2024-03-01 12:19:22.539           12      card
# 2 2024-03-01 2024-03-01 12:20:18.089           12      card
# 3 2024-03-01 2024-03-01 13:46:33.006           13      card
# 4 2024-03-01 2024-03-01 13:48:14.626           13      card
#
#                   card  money    coffee_name Time_of_Day Weekday Month_name  \
# 0  ANON-0000-0000-0001   38.7          Latte     Morning     Fri        Mar
# 1  ANON-0000-0000-0002   38.7  Hot Chocolate   Afternoon     Fri        Mar
# 2  ANON-0000-0000-0002   38.7  Hot Chocolate   Afternoon     Fri        Mar
# 3  ANON-0000-0000-0003   28.9      Americano   Afternoon     Fri        Mar
# 4  ANON-0000-0000-0004   38.7          Latte   Afternoon     Fri        Mar
#
#    Weekdaysort  Monthsort
# 0            5          3
# 1            5          3
# 2            5          3
# 3            5          3
# ...

# %%
CS.tail()
# Out:
#            date                datetime  hour_of_day cash_type  \
# 3631 2025-03-23 2025-03-23 10:34:54.894           10      card
# 3632 2025-03-23 2025-03-23 14:43:37.362           14      card
# 3633 2025-03-23 2025-03-23 14:44:16.864           14      card
# 3634 2025-03-23 2025-03-23 15:47:28.723           15      card
# 3635 2025-03-23 2025-03-23 18:11:38.635           18      card
#
#                      card  money coffee_name Time_of_Day Weekday Month_name  \
# 3631  ANON-0000-0000-1158  35.76  Cappuccino     Morning     Sun        Mar
# 3632  ANON-0000-0000-1315  35.76       Cocoa   Afternoon     Sun        Mar
# 3633  ANON-0000-0000-1315  35.76       Cocoa   Afternoon     Sun        Mar
# 3634  ANON-0000-0000-1316  25.96   Americano   Afternoon     Sun        Mar
# 3635  ANON-0000-0000-1275  35.76       Latte       Night     Sun        Mar
#
#       Weekdaysort  Monthsort
# 3631            7          3
# 3632            7          3
# 3633            7          3
# ...

# %%
CS.sample()
# Out:
#           date                datetime  hour_of_day cash_type  \
# 496 2024-05-16 2024-05-16 18:12:56.934           18      card
#
#                     card  money    coffee_name Time_of_Day Weekday Month_name  \
# 496  ANON-0000-0000-0175  37.72  Hot Chocolate       Night     Thu        May
#
#      Weekdaysort  Monthsort
# 496            4          5

# %%
CS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3636 entries, 0 to 3635
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3636 non-null   datetime64[ns]
#  1   datetime     3636 non-null   datetime64[ns]
#  2   hour_of_day  3636 non-null   int64
#  3   cash_type    3636 non-null   object
#  4   card         3547 non-null   object
#  5   money        3636 non-null   float64
#  6   coffee_name  3636 non-null   object
#  7   Time_of_Day  3636 non-null   object
#  8   Weekday      3636 non-null   object
#  9   Month_name   3636 non-null   object
#  10  Weekdaysort  3636 non-null   int64
#  11  Monthsort    3636 non-null   int64
# dtypes: datetime64[ns](2), float64(1), int64(3), object(6)
# memory usage: 341.0+ KB

# %%
CS.describe()
# Out:
#                                 date                       datetime  \
# count                           3636                           3636
# mean   2024-09-30 11:56:02.376237568  2024-10-01 02:35:30.535053568
# min              2024-03-01 00:00:00     2024-03-01 10:15:50.520000
# 25%              2024-07-03 00:00:00  2024-07-03 16:54:06.084750080
# 50%              2024-10-06 12:00:00  2024-10-07 02:55:12.649500160
# 75%              2025-01-08 00:00:00  2025-01-08 07:55:20.299750144
# max              2025-03-23 00:00:00     2025-03-23 18:11:38.635000
# std                              NaN                            NaN
#
#        hour_of_day        money  Weekdaysort    Monthsort
# count  3636.000000  3636.000000  3636.000000  3636.000000
# mean     14.166942    31.746859     3.847910     6.394664
# min       6.000000    18.120000     1.000000     1.000000
# 25%      10.000000    27.920000     2.000000     3.000000
# 50%      14.000000    32.820000     4.000000     6.000000
# ...

# %%
CS.duplicated().unique()
# Out:
# array([False])

# %%
CS.isnull()
# Out:
#        date  datetime  hour_of_day  cash_type   card  money  coffee_name  \
# 0     False     False        False      False  False  False        False
# 1     False     False        False      False  False  False        False
# 2     False     False        False      False  False  False        False
# 3     False     False        False      False  False  False        False
# 4     False     False        False      False  False  False        False
# ...     ...       ...          ...        ...    ...    ...          ...
# 3631  False     False        False      False  False  False        False
# 3632  False     False        False      False  False  False        False
# 3633  False     False        False      False  False  False        False
# 3634  False     False        False      False  False  False        False
# 3635  False     False        False      False  False  False        False
#
#       Time_of_Day  Weekday  Month_name  Weekdaysort  Monthsort
# ...

# %%
CS.isnull().sum()
# Out:
# date            0
# datetime        0
# hour_of_day     0
# cash_type       0
# card           89
# money           0
# coffee_name     0
# Time_of_Day     0
# Weekday         0
# Month_name      0
# Weekdaysort     0
# Monthsort       0
# dtype: int64

# %%
filter=CS[CS['card'].isnull()]
filter
# Out:
#           date                datetime  hour_of_day cash_type card  money  \
# 12  2024-03-02 2024-03-02 10:30:35.668           10      cash  NaN   40.0
# 18  2024-03-03 2024-03-03 10:10:43.981           10      cash  NaN   40.0
# 41  2024-03-06 2024-03-06 12:30:27.089           12      cash  NaN   35.0
# 46  2024-03-07 2024-03-07 10:08:58.945           10      cash  NaN   40.0
# 49  2024-03-07 2024-03-07 11:25:43.977           11      cash  NaN   40.0
# ..         ...                     ...          ...       ...  ...    ...
# 657 2024-05-31 2024-05-31 09:23:58.791            9      cash  NaN   39.0
# 677 2024-06-01 2024-06-01 20:54:59.267           20      cash  NaN   39.0
# 685 2024-06-02 2024-06-02 22:43:10.636           22      cash  NaN   34.0
# 691 2024-06-03 2024-06-03 21:42:51.734           21      cash  NaN   34.0
# 692 2024-06-03 2024-06-03 21:43:37.471           21      cash  NaN   34.0
#
#              coffee_name Time_of_Day Weekday Month_name  Weekdaysort  \
# ...

# %%
CS['card'].isnull().sum()
# Out:
# np.int64(89)

# %%
CS['card']=CS['card'].fillna('-')
CS['card']
# Out:
# 0       ANON-0000-0000-0001
# 1       ANON-0000-0000-0002
# 2       ANON-0000-0000-0002
# 3       ANON-0000-0000-0003
# 4       ANON-0000-0000-0004
#                ...
# 3631    ANON-0000-0000-1158
# 3632    ANON-0000-0000-1315
# 3633    ANON-0000-0000-1315
# 3634    ANON-0000-0000-1316
# 3635    ANON-0000-0000-1275
# Name: card, Length: 3636, dtype: object

# %%
CS['card'].isnull().sum()
# Out:
# np.int64(0)

# %%
CS
# Out:
#            date                datetime  hour_of_day cash_type  \
# 0    2024-03-01 2024-03-01 10:15:50.520           10      card
# 1    2024-03-01 2024-03-01 12:19:22.539           12      card
# 2    2024-03-01 2024-03-01 12:20:18.089           12      card
# 3    2024-03-01 2024-03-01 13:46:33.006           13      card
# 4    2024-03-01 2024-03-01 13:48:14.626           13      card
# ...         ...                     ...          ...       ...
# 3631 2025-03-23 2025-03-23 10:34:54.894           10      card
# 3632 2025-03-23 2025-03-23 14:43:37.362           14      card
# 3633 2025-03-23 2025-03-23 14:44:16.864           14      card
# 3634 2025-03-23 2025-03-23 15:47:28.723           15      card
# 3635 2025-03-23 2025-03-23 18:11:38.635           18      card
#
#                      card  money    coffee_name Time_of_Day Weekday  \
# 0     ANON-0000-0000-0001  38.70          Latte     Morning     Fri
# 1     ANON-0000-0000-0002  38.70  Hot Chocolate   Afternoon     Fri
# ...

# %%
CS['Day']=CS['date'].dt.day
CS['Day']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 3631    23
# 3632    23
# 3633    23
# 3634    23
# 3635    23
# Name: Day, Length: 3636, dtype: int32

# %%
CS['Month']=CS['date'].dt.month
CS['Month']
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 3631    3
# 3632    3
# 3633    3
# 3634    3
# 3635    3
# Name: Month, Length: 3636, dtype: int32

# %%
CS['Year']=CS['date'].dt.year
CS['Year']
# Out:
# 0       2024
# 1       2024
# 2       2024
# 3       2024
# 4       2024
#         ...
# 3631    2025
# 3632    2025
# 3633    2025
# 3634    2025
# 3635    2025
# Name: Year, Length: 3636, dtype: int32

# %%
CS
# Out:
#            date                datetime  hour_of_day cash_type  \
# 0    2024-03-01 2024-03-01 10:15:50.520           10      card
# 1    2024-03-01 2024-03-01 12:19:22.539           12      card
# 2    2024-03-01 2024-03-01 12:20:18.089           12      card
# 3    2024-03-01 2024-03-01 13:46:33.006           13      card
# 4    2024-03-01 2024-03-01 13:48:14.626           13      card
# ...         ...                     ...          ...       ...
# 3631 2025-03-23 2025-03-23 10:34:54.894           10      card
# 3632 2025-03-23 2025-03-23 14:43:37.362           14      card
# 3633 2025-03-23 2025-03-23 14:44:16.864           14      card
# 3634 2025-03-23 2025-03-23 15:47:28.723           15      card
# 3635 2025-03-23 2025-03-23 18:11:38.635           18      card
#
#                      card  money    coffee_name Time_of_Day Weekday  \
# 0     ANON-0000-0000-0001  38.70          Latte     Morning     Fri
# 1     ANON-0000-0000-0002  38.70  Hot Chocolate   Afternoon     Fri
# ...

# %%
CS['coffee_name'].unique()
# Out:
# array(['Latte', 'Hot Chocolate', 'Americano', 'Americano with Milk',
#        'Cocoa', 'Cortado', 'Espresso', 'Cappuccino'], dtype=object)

# %%
CS['coffee_name'].nunique()
# Out:
# 8

# %%
CS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3636 entries, 0 to 3635
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3636 non-null   datetime64[ns]
#  1   datetime     3636 non-null   datetime64[ns]
#  2   hour_of_day  3636 non-null   int64
#  3   cash_type    3636 non-null   object
#  4   card         3636 non-null   object
#  5   money        3636 non-null   float64
#  6   coffee_name  3636 non-null   object
#  7   Time_of_Day  3636 non-null   object
#  8   Weekday      3636 non-null   object
#  9   Month_name   3636 non-null   object
#  10  Weekdaysort  3636 non-null   int64
#  11  Monthsort    3636 non-null   int64
#  12  Day          3636 non-null   int32
#  13  Month        3636 non-null   int32
#  14  Year         3636 non-null   int32
# dtypes: datetime64[ns](2), float64(1), int32(3), int64(3), object(6)
# memory usage: 383.6+ KB

# %%
CS['Day']=pd.to_datetime(CS['date'])
daily_sales=CS.groupby('Day')['money'].sum().reset_index()
daily_sales
# Out:
#            Day   money
# 0   2024-03-01  396.30
# 1   2024-03-02  228.10
# 2   2024-03-03  349.10
# 3   2024-03-04  135.20
# 4   2024-03-05  338.50
# ..         ...     ...
# 376 2025-03-19  623.56
# 377 2025-03-20  597.60
# 378 2025-03-21  636.80
# 379 2025-03-22  365.42
# 380 2025-03-23  204.76
#
# [381 rows x 2 columns]

# %%
CS['Month']=CS['date'].dt.to_period('M')
monthly_sales=CS.groupby('Month')['money'].sum().reset_index()
monthly_sales
# Out:
#       Month     money
# 0   2024-03   7050.20
# 1   2024-04   6720.56
# 2   2024-05   9063.42
# 3   2024-06   7758.76
# 4   2024-07   6915.94
# 5   2024-08   7613.84
# 6   2024-09   9988.64
# 7   2024-10  13891.16
# 8   2024-11   8590.54
# 9   2024-12   8237.74
# 10  2025-01   6398.86
# 11  2025-02  13215.48
# 12  2025-03   9986.44

# %%
CS['Year']=CS['date'].dt.year
yearly_sales=CS.groupby('Year')['money'].sum().reset_index()
yearly_sales
# Out:
#    Year     money
# 0  2024  85830.80
# 1  2025  29600.78

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(25,6))
plt.plot(daily_sales['Day'],daily_sales['money'],marker='o',color='g')
plt.title('Daily Sales Trend')
plt.xlabel('Date')
plt.ylabel('Money')
plt.grid(True)
plt.show()

# %%
plt.plot(monthly_sales['Month'].astype(str),monthly_sales['money'],marker='D',linestyle='dashed',color='g')
plt.title('Monthly Sales Trend')
plt.xlabel('Date')
plt.ylabel('Money')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
plt.plot(yearly_sales['Year'],yearly_sales['money'],marker='o',color='g')
plt.title('Yearly Sales Trend')
plt.xlabel('Date')
plt.ylabel('Money')
plt.show()

# %%
import seaborn as sns
numeric_CS = CS.select_dtypes(include=['number'])
sns.heatmap(numeric_CS.corr(), annot=True, cmap='YlGnBu')
plt.show()

# %%
grouped=CS.groupby(['coffee_name','Time_of_Day'])['Weekdaysort'].sum()
grouped
# Out:
# coffee_name          Time_of_Day
# Americano            Afternoon       894
#                      Morning         811
#                      Night           450
# Americano with Milk  Afternoon      1033
#                      Morning        1218
#                      Night           899
# Cappuccino           Afternoon       696
#                      Morning         506
#                      Night           793
# Cocoa                Afternoon       304
#                      Morning         221
#                      Night           378
# Cortado              Afternoon       388
#                      Morning         601
#                      Night           230
# Espresso             Afternoon       233
#                      Morning         197
#                      Night           111
# Hot Chocolate        Afternoon       357
#                      Morning         173
#                      Night           576
# Latte                Afternoon      1071
# ...

# %%
filter=CS[CS['cash_type']=='cash']
filter
# Out:
#           date                datetime  hour_of_day cash_type card  money  \
# 12  2024-03-02 2024-03-02 10:30:35.668           10      cash    -   40.0
# 18  2024-03-03 2024-03-03 10:10:43.981           10      cash    -   40.0
# 41  2024-03-06 2024-03-06 12:30:27.089           12      cash    -   35.0
# 46  2024-03-07 2024-03-07 10:08:58.945           10      cash    -   40.0
# 49  2024-03-07 2024-03-07 11:25:43.977           11      cash    -   40.0
# ..         ...                     ...          ...       ...  ...    ...
# 657 2024-05-31 2024-05-31 09:23:58.791            9      cash    -   39.0
# 677 2024-06-01 2024-06-01 20:54:59.267           20      cash    -   39.0
# 685 2024-06-02 2024-06-02 22:43:10.636           22      cash    -   34.0
# 691 2024-06-03 2024-06-03 21:42:51.734           21      cash    -   34.0
# 692 2024-06-03 2024-06-03 21:43:37.471           21      cash    -   34.0
#
#              coffee_name Time_of_Day Weekday Month_name  Weekdaysort  \
# ...

# %%
grouped=CS.groupby(['coffee_name','Time_of_Day'])['money'].sum()
grouped
# Out:
# coffee_name          Time_of_Day
# Americano            Afternoon       6308.94
#                      Morning         5820.10
#                      Night           2933.22
# Americano with Milk  Afternoon       7557.36
#                      Morning        10199.52
#                      Night           7512.24
# Cappuccino           Afternoon       6110.70
#                      Morning         4486.44
#                      Night           7437.00
# Cocoa                Afternoon       2725.92
#                      Morning         2098.38
#                      Night           3853.86
# Cortado              Afternoon       2405.84
#                      Morning         3665.46
#                      Night           1463.56
# Espresso             Afternoon       1239.16
#                      Morning          922.72
#                      Night            652.40
# Hot Chocolate        Afternoon       2979.02
#                      Morning         1784.40
# ...

# %%
CS['hour_of_day'].unique()
# Out:
# array([10, 12, 13, 15, 16, 18, 19, 11, 14, 17,  9,  7, 20,  8, 22, 21,  6])

# %%
grouped=CS.groupby(['coffee_name','date'])['money'].sum()
grouped
# Out:
# coffee_name  date
# Americano    2024-03-01     28.90
#              2024-03-02     86.70
#              2024-03-03     28.90
#              2024-03-06     28.90
#              2024-03-07     28.90
#                             ...
# Latte        2025-03-19    107.28
#              2025-03-20     35.76
#              2025-03-21    214.56
#              2025-03-22     35.76
#              2025-03-23     71.52
# Name: money, Length: 1711, dtype: float64

# %%
coffee_price=CS.groupby('coffee_name')['money'].sum().sort_values(ascending=False)
coffee_price
# Out:
# coffee_name
# Latte                  27866.30
# Americano with Milk    25269.12
# Cappuccino             18034.14
# Americano              15062.26
# Hot Chocolate          10172.46
# Cocoa                   8678.16
# Cortado                 7534.86
# Espresso                2814.28
# Name: money, dtype: float64

# %%
CS['coffee_name'].unique()
# Out:
# array(['Latte', 'Hot Chocolate', 'Americano', 'Americano with Milk',
#        'Cocoa', 'Cortado', 'Espresso', 'Cappuccino'], dtype=object)

# %%
Latte_sales=CS[CS['coffee_name']=='Latte'].shape[0]
Latte_sales
# Out:
# 782

# %%
grouped=CS.groupby(['coffee_name','Weekday']).agg({'money':['sum','min','max','count']})
grouped
# Out:
#                                money
#                                  sum    min    max count
# coffee_name         Weekday
# Americano           Fri      2766.58  23.02  30.00   106
#                     Mon      2568.12  23.02  30.00    98
#                     Sat      1847.28  23.02  29.00    71
#                     Sun      1248.28  23.02  30.00    48
#                     Thu      2153.82  23.02  30.00    83
#                     Tue      2168.62  23.02  30.00    83
#                     Wed      2309.56  23.02  29.00    89
# Americano with Milk Fri      3230.90  27.92  34.00   105
#                     Mon      4053.78  27.92  35.00   132
#                     Sat      3754.86  27.92  35.00   121
#                     Sun      3157.88  27.92  35.00   103
#                     Thu      3156.04  27.92  33.80   103
#                     Tue      4436.60  27.92  35.00   146
#                     Wed      3479.06  27.92  35.00   114
# ...

# %%
Latte_sales=CS[CS['coffee_name']=='Latte']
Latte_sales
# Out:
#            date                datetime  hour_of_day cash_type  \
# 0    2024-03-01 2024-03-01 10:15:50.520           10      card
# 4    2024-03-01 2024-03-01 13:48:14.626           13      card
# 12   2024-03-02 2024-03-02 10:30:35.668           10      cash
# 18   2024-03-03 2024-03-03 10:10:43.981           10      cash
# 19   2024-03-03 2024-03-03 10:27:18.561           10      card
# ...         ...                     ...          ...       ...
# 3615 2025-03-21 2025-03-21 17:22:49.875           17      card
# 3616 2025-03-21 2025-03-21 18:52:12.666           18      card
# 3627 2025-03-22 2025-03-22 16:26:59.766           16      card
# 3630 2025-03-23 2025-03-23 10:07:11.278           10      card
# 3635 2025-03-23 2025-03-23 18:11:38.635           18      card
#
#                      card  money coffee_name Time_of_Day Weekday Month_name  \
# 0     ANON-0000-0000-0001  38.70       Latte     Morning     Fri        Mar
# ...

# %%
plt.bar(CS['coffee_name'],CS['money'],color='y')
plt.title('Sales by Coffee Name')
plt.xlabel('Coffee Name')
plt.ylabel('Money')
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %%
plt.bar(CS['Time_of_Day'],CS['money'],align='center',color='y')
plt.title('Sales by Time of Day')
plt.xlabel('Time of Day')
plt.ylabel('Money')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
grouped=CS.groupby('cash_type')['money'].sum()
grouped
# Out:
# cash_type
# card    112245.58
# cash      3186.00
# Name: money, dtype: float64

# %%
plt.bar(CS['cash_type'],CS['money'],align='center',color='y')
plt.title('Sales by cash_type')
plt.xlabel('cash_type')
plt.ylabel('Money')
# Out:
# Text(0, 0.5, 'Money')

# %%
from textblob import TextBlob
text="I really love this coffee!"
blob=TextBlob(text)
sentiment=blob.sentiment.polarity
sentiment
# Out:
# 0.625

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')

analyzer = SentimentIntensityAnalyzer()
text = "That movie was absolutely amazing!"

score = analyzer.polarity_scores(text)
print(score)
# Out:
# {'neg': 0.0, 'neu': 0.477, 'pos': 0.523, 'compound': 0.6581}
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
